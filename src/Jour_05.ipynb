# %% [markdown]
# # Visualisation avec scatter plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Charger le jeu de données Iris
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 1. Scatter plot simple
plt.figure(figsize=(10, 6))
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species')
plt.title('Scatter plot: Sepal Length vs Sepal Width')
plt.show()

# %%
# 2. Pairplot
sns.pairplot(iris, hue='species')
plt.show()

# %%
# 3. Scatter plot avec régression
plt.figure(figsize=(10, 6))
sns.lmplot(data=iris, x='petal_length', y='petal_width', hue='species', height=6)
plt.title('Scatter plot avec régression: Petal Length vs Petal Width')
plt.show()

# %%
# 4. Box plot
plt.figure(figsize=(12, 6))
sns.boxplot(data=iris, x='species', y='sepal_length')
plt.title('Box plot: Sepal Length par espèce')
plt.show()

# %%
# 5. Violin plot
plt.figure(figsize=(12, 6))
sns.violinplot(data=iris, x='species', y='petal_width')
plt.title('Violin plot: Petal Width par espèce')
plt.show()
